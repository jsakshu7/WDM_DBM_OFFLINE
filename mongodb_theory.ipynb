# %% [markdown]
# # 📘 Introduction to MongoDB
#
# ## ✅ What is MongoDB?
# - **MongoDB** is a **NoSQL** (non-relational) database.
# - It stores data in **JSON-like** documents (called **BSON** – Binary JSON).
# - Unlike traditional databases (like MySQL), it doesn’t store data in rows and tables, but in **collections and documents**.
#
# ---# 📘 Introduction to MongoDB
#
# ## ✅ What is MongoDB?
# - **MongoDB** is a **NoSQL** (non-relational) database.
# - It stores data in **JSON-like** documents (called **BSON** – Binary JSON).
# - Unlike traditional databases (like MySQL), it doesn’t store data in rows and tables, but in **collections and documents**.
#
# ---
#
# ## 📂 Structure of MongoDB
#
# | Relational DB | MongoDB         |
# |---------------|-----------------|
# | Database      | Database        |
# | Table         | Collection      |
# | Row           | Document        |
# | Column        | Field (key)     |
#
# ### 📄 Example Document:
# ```json
# {
#   "_id": 1,
#   "name": "John",
#   "age": 25,
#   "skills": ["Python", "MongoDB"]
# }
#
# ## 📂 Structure of MongoDB
#
# | Relational DB | MongoDB         |
# |---------------|-----------------|
# | Database      | Database        |
# | Table         | Collection      |
# | Row           | Document        |
# | Column        | Field (key)     |
#
# ### 📄 Example Document:
# ```json
# {
#   "_id": 1,
#   "name": "John",
#   "age": 25,
#   "skills": ["Python", "MongoDB"]
# }

# %% [markdown]
# ```js
#
# // Show all databases
# show dbs
#
# // Use (or create) a database
# use mydb
#
# // Show all collections in a DB
# show collections
#
# // Insert a document
# db.students.insertOne({name: "Alice", age: 22})
#
# // Find documents
# db.students.find()
#
# // Update a document
# db.students.updateOne({name: "Alice"}, {$set: {age: 23}})
#
# // Delete a document
# db.students.deleteOne({name: "Alice"})
#
# ```

# %% [markdown]
# # 🔄 Difference Between SQL and MongoDB
#
# | Feature                | SQL (Relational Database)           | MongoDB (NoSQL Database)           |
# |------------------------|-------------------------------------|-------------------------------------|
# | **Data Structure**     | Tables (Rows and Columns)           | Collections (Documents)             |
# | **Schema**             | Fixed Schema                        | Schema-less (Flexible Structure)    |
# | **Data Format**        | Relational (Structured)             | JSON-like (BSON)                    |
# | **Query Language**     | SQL (Structured Query Language)     | MQL (MongoDB Query Language)        |
# | **Joins**              | Supports complex joins              | Limited joins; prefers embedding    |
# |
# | **Example Insertion**  | `INSERT INTO students VALUES(...)`  | `db.students.insertOne({...})`     |
# | **Example Retrieval**  | `SELECT * FROM students`            | `db.students.find()`               |
# | **Best For**           | Banking, ERP systems, legacy apps   | Real-time apps, social media, IoT   |
#
# ---
